# %% [markdown]
# This project is created by Yagnam Joshi
# 9th April 2024

# %% [markdown]
# Email: joshiyagnam@outlook.com

# %% [markdown]
# Phone number: +91 7984374916

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1=pd.read_csv(r"C:\Users\Yagnam Joshi\Downloads\Questions-female (Responses).csv")
df1
# Out:
#            Timestamp                  Email Address               Name  \
# 0   04-09-2024 10:00       Aisha.Sharma@example.com       Aisha Sharma
# 1   04-09-2024 10:01         Neha.Gupta@example.com         Neha Gupta
# 2   04-09-2024 10:02        Priya.Patel@example.com        Priya Patel
# 3   04-09-2024 10:03      Shreya.Chopra@example.com      Shreya Chopra
# 4   04-09-2024 10:04       Pooja.Sharma@example.com       Pooja Sharma
# 5   04-09-2024 10:05         Riya.Patel@example.com         Riya Patel
# 6   04-09-2024 10:06       Nisha.Kapoor@example.com       Nisha Kapoor
# 7   04-09-2024 10:07       Meera.Sharma@example.com       Meera Sharma
# 8   04-09-2024 10:08        Simran.Gill@example.com        Simran Gill
# 9   04-09-2024 10:09     Priya.Malhotra@example.com     Priya Malhotra
# 10  04-09-2024 10:10        Anjali.Jain@example.com        Anjali Jain
# 11  04-09-2024 10:11       Sakshi.Arora@example.com       Sakshi Arora
# ...

# %%
df2 = pd.read_csv(r"C:\Users\Yagnam Joshi\Downloads\Questions-male (Responses).csv")
df2
# Out:
#           Timestamp              Email Address           Name  \
# 0  04-09-2024 12:00   Rahul.sharma@example.com   Rahul Sharma
# 1  04-09-2024 12:01     Isha.patel@example.com     Isha Patel
# 2  04-09-2024 12:02    Arjun.kumar@example.com    Arjun Kumar
# 3  04-09-2024 12:03     Neha.gupta@example.com     Neha Gupta
# 4  04-09-2024 12:04    Sahil.patel@example.com    Sahil Patel
# 5  04-09-2024 12:05   Priya.sharma@example.com   Priya Sharma
# 6  04-09-2024 12:06   Rohan.kapoor@example.com   Rohan Kapoor
# 7  04-09-2024 12:07  Pooja.agarwal@example.com  Pooja Agarwal
# 8  04-09-2024 12:08    Neel.sharma@example.com    Neel Sharma
# 9  04-09-2024 12:09     Riya.gupta@example.com     Riya Gupta
#
#   Do you make an effort to understand your partner's feelings during difficult times?  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# ...

# %%
female_01 = df1.iloc[0]
yes_count = female_01.eq('Yes').sum()
compatibility_female=yes_count/30*100
print(f"Comatibility of female: {compatibility_female} percent")
# Out:
# Comatibility of female: 80.0 percent

# %%
male_01=df2.iloc[0]
yes_count=male_01.eq('Yes').sum()
compatibility_male=yes_count/30*100
print(f"Compatibilty of male: {compatibility_male} percent")
# Out:
# Compatibilty of male: 90.0 percent

# %%
couple_compatibilty=(compatibility_female+compatibility_male)/2
print(f"Couple's compatibilty is: {couple_compatibilty} percent")
# Out:
# Couple's compatibilty is: 85.0 percent

# %%
if couple_compatibilty>=80:
    print("Rab ne banadi jodi is all this checker can say about you")
    print(f"Be happy as you are compatibile for eachoter with {couple_compatibilty} percent")
elif couple_compatibilty>=60 and couple_compatibilty<80:
    print("God makes all different but simmilarity is what brings you both together")
    print('There might be some turbulances, but you two will get along fine')
else:
    print(f'Your comatibility is {couple_compatibilty}, you need to resolve on issues')
# Out:
# Rab ne banadi jodi is all this checker can say about you
# Be happy as you are compatibile for eachoter with 85.0 percent
